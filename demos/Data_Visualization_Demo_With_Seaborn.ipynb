# %% [markdown]
# <a href="https://colab.research.google.com/github/naica922/uek_259_MachieneLearning/blob/main/demos/Data_Visualization_Demo_With_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualization with Seaborn

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/LuWidme/uk259/blob/main/demos/Visualization_With_Seaborn.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# Matplotlib has been at the core of scientific visualization in Python for decades, but even avid users will admit it often leaves much to be desired.
# There are several complaints about Matplotlib that often come up:
#
# - A common early complaint, which is now outdated: prior to version 2.0, Matplotlib's color and style defaults were at times poor and looked dated.
# - Matplotlib's API is relatively low-level. Doing sophisticated statistical visualization is possible, but often requires a *lot* of boilerplate code.
# - Matplotlib predated Pandas by more than a decade, and thus is not designed for use with Pandas `DataFrame` objects. In order to visualize data from a `DataFrame`, you must extract each `Series` and often concatenate them together into the right format. It would be nicer to have a plotting library that can intelligently use the `DataFrame` labels in a plot.
#
# An answer to these problems is [Seaborn](http://seaborn.pydata.org/). Seaborn provides an API on top of Matplotlib that offers sane choices for plot style and color defaults, defines simple high-level functions for common statistical plot types, and integrates with the functionality provided by Pandas.
#
# To be fair, the Matplotlib team has adapted to the changing landscape: it added the `plt.style` tools discussed in [Customizing Matplotlib: Configurations and Style Sheets](04.11-Settings-and-Stylesheets.ipynb), and Matplotlib is starting to handle Pandas data more seamlessly.
# But for all the reasons just discussed, Seaborn remains a useful add-on.
#
# By convention, Seaborn is often imported as `sns`:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

sns.set()  # seaborn's method to set its chart style

# %% [markdown]
# ## Exploring Seaborn Plots
#
# The main idea of Seaborn is that it provides high-level commands to create a variety of plot types useful for statistical data exploration, and even some statistical model fitting.
#
# Let's take a look at a few of the datasets and plot types available in Seaborn. Note that all of the following *could* be done using raw Matplotlib commands (this is, in fact, what Seaborn does under the hood), but the Seaborn API is much more convenient.

# %% [markdown]
# ### Histograms, KDE, and Densities
#
# Often in statistical data visualization, all you want is to plot histograms and joint distributions of variables.
# We have seen that this is relatively straightforward in Matplotlib (see the following figure):

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], density=True, alpha=0.5)

# %% [markdown]
# Rather than just providing a histogram as a visual output, we can get a smooth estimate of the distribution using kernel density estimation (introduced in [Density and Contour Plots](04.04-Density-and-Contour-Plots.ipynb)), which Seaborn does with ``sns.kdeplot`` (see the following figure):

# %%
sns.kdeplot(data=data, shade=True);
# Out:
# /tmp/ipython-input-527-2427864141.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, shade=True);

# %% [markdown]
# If we pass `x` and `y` columns to `kdeplot`, we instead get a two-dimensional visualization of the joint density (see the following figure):

# %%
sns.kdeplot(data=data, x='x', y='y');

# %% [markdown]
# We can see the joint distribution and the marginal distributions together using `sns.jointplot`, which we'll explore further later in this chapter.

# %% [markdown]
# ### Pair Plots
#
# When you generalize joint plots to datasets of larger dimensions, you end up with *pair plots*. These are very useful for exploring correlations between multidimensional data, when you'd like to plot all pairs of values against each other.
#
# We'll demo this with the well-known Iris dataset, which lists measurements of petals and sepals of three Iris species:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Visualizing the multidimensional relationships among the samples is as easy as calling ``sns.pairplot`` (see the following figure):

# %%
sns.pairplot(iris, hue='species', height=2.5);

# %% [markdown]
# ### Faceted Histograms
#
# Sometimes the best way to view data is via histograms of subsets, as shown in the following figure. Seaborn's `FacetGrid` makes this simple.
# We'll take a look at some data that shows the amount that restaurant staff receive in tips based on various indicator data:[^1]
#
# [^1]: The restaurant staff data used in this section divides employees into two sexes: female and male. Biological sex
# isn’t binary, but the following discussion and visualizations are limited by this data.

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));

# %% [markdown]
# The faceted chart gives us some quick insights into the dataset: for example, we see that it contains far more data on male servers during the dinner hour than other categories, and typical tip amounts appear to range from approximately 10% to 20%, with some outliers on either end.
#
# ### Categorical Plots
#
# Categorical plots can be useful for this kind of visualization as well. These allow you to view the distribution of a parameter within bins defined by any other parameter, as shown in the following figure:

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot(x="day", y="total_bill", hue="sex", data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill");

# %% [markdown]
# ### Joint Distributions
#
# Similar to the pair plot we saw earlier, we can use `sns.jointplot` to show the joint distribution between different datasets, along with the associated marginal distributions (see the following figure):

# %%
with sns.axes_style('white'):
    sns.jointplot(x="total_bill", y="tip", data=tips, kind='hex')

# %% [markdown]
# The joint plot can even do some automatic kernel density estimation and regression, as shown in the following figure:

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind='reg');

# %% [markdown]
# ### Bar Plots
#
# Time series can be plotted using `sns.factorplot`. In the following example, we'll use the Planets dataset that we first saw in [Aggregation and Grouping](03.08-Aggregation-and-Grouping.ipynb); see the following figure for the result:

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="year", data=planets, aspect=2,
                    kind="count", color='steelblue')
    g.set_xticklabels(step=5)

# %% [markdown]
# We can learn more by looking at the *method* of discovery of each of these planets (see the following figure):

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="year", data=planets, aspect=4.0, kind='count',
                    hue='method', order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')

# %% [markdown]
# For more information on plotting with Seaborn, see the [Seaborn documentation](http://seaborn.pydata.org/), and particularly the [example gallery](https://seaborn.pydata.org/examples/index.html).

# %% [markdown]
# ## Example: Exploring Marathon Finishing Times
#
# Here we'll look at using Seaborn to help visualize and understand finishing results from a marathon.
# I've scraped the data from sources on the web, aggregated it and removed any identifying information, and put it on GitHub, where it can be downloaded
# (if you are interested in using Python for web scraping, I would recommend [*Web Scraping with Python*](http://shop.oreilly.com/product/0636920034391.do) by Ryan Mitchell, also from O'Reilly).
# We will start by downloading the data and loading it into Pandas:[^2]
#
# [^2]: The marathon data used in this section divides runners into two genders: men and women. While gender is a
# spectrum, the following discussion and visualizations use this binary because they depend on the data.

# %%
# url = ('https://raw.githubusercontent.com/jakevdp/'
#        'marathon-data/master/marathon-data.csv')
# !cd data && curl -O {url}

# %%
data = pd.read_csv('https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv')
data.head()
# Out:
#    age gender     split     final
# 0   33      M  01:05:38  02:08:51
# 1   32      M  01:06:26  02:09:28
# 2   31      M  01:06:49  02:10:42
# 3   38      M  01:06:16  02:13:45
# 4   31      M  01:06:32  02:13:59

# %% [markdown]
# Notice that Pandas loaded the time columns as Python strings (type `object`); we can see this by looking at the `dtypes` attribute of the `DataFrame`:

# %%
data.dtypes
# Out:
# age        int64
# gender    object
# split     object
# final     object
# dtype: object

# %% [markdown]
# Let's fix this by providing a converter for the times:

# %%
import datetime

def convert_time(s):
    h, m, s = map(int, s.split(':'))
    return datetime.timedelta(hours=h, minutes=m, seconds=s)

data = pd.read_csv('https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv',
                   converters={'split':convert_time, 'final':convert_time})
data.head()
# Out:
#    age gender           split           final
# 0   33      M 0 days 01:05:38 0 days 02:08:51
# 1   32      M 0 days 01:06:26 0 days 02:09:28
# 2   31      M 0 days 01:06:49 0 days 02:10:42
# 3   38      M 0 days 01:06:16 0 days 02:13:45
# 4   31      M 0 days 01:06:32 0 days 02:13:59

# %%
data.dtypes
# Out:
# age                 int64
# gender             object
# split     timedelta64[ns]
# final     timedelta64[ns]
# dtype: object

# %% [markdown]
# That will make it easier to manipulate the temporal data. For the purpose of our Seaborn plotting utilities, let's next add columns that give the times in seconds:

# %%
data['split_sec'] = data['split'].view(int) / 1E9
data['final_sec'] = data['final'].view(int) / 1E9
data.head()
# Out:
# /tmp/ipython-input-544-1313223546.py:1: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   data['split_sec'] = data['split'].view(int) / 1E9
# /tmp/ipython-input-544-1313223546.py:2: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   data['final_sec'] = data['final'].view(int) / 1E9
#    age gender           split           final  split_sec  final_sec
# 0   33      M 0 days 01:05:38 0 days 02:08:51     3938.0     7731.0
# 1   32      M 0 days 01:06:26 0 days 02:09:28     3986.0     7768.0
# 2   31      M 0 days 01:06:49 0 days 02:10:42     4009.0     7842.0
# 3   38      M 0 days 01:06:16 0 days 02:13:45     3976.0     8025.0
# 4   31      M 0 days 01:06:32 0 days 02:13:59     3992.0     8039.0

# %% [markdown]
# To get an idea of what the data looks like, we can plot a `jointplot` over the data; the following figure shows the result:

# %%
with sns.axes_style('white'):
    g = sns.jointplot(x='split_sec', y='final_sec', data=data, kind='hex')
    g.ax_joint.plot(np.linspace(4000, 16000),
                    np.linspace(8000, 32000), ':k')

# %% [markdown]
# The dotted line shows where someone's time would lie if they ran the marathon at a perfectly steady pace. The fact that the distribution lies above this indicates (as you might expect) that most people slow down over the course of the marathon.
# If you have run competitively, you'll know that those who do the opposite—run faster during the second half of the race—are said to have "negative-split" the race.
#
# Let's create another column in the data, the split fraction, which measures the degree to which each runner negative-splits or positive-splits the race:

# %%
data['split_frac'] = 1 - 2 * data['split_sec'] / data['final_sec']
data.head()
# Out:
#    age gender           split           final  split_sec  final_sec  \
# 0   33      M 0 days 01:05:38 0 days 02:08:51     3938.0     7731.0
# 1   32      M 0 days 01:06:26 0 days 02:09:28     3986.0     7768.0
# 2   31      M 0 days 01:06:49 0 days 02:10:42     4009.0     7842.0
# 3   38      M 0 days 01:06:16 0 days 02:13:45     3976.0     8025.0
# 4   31      M 0 days 01:06:32 0 days 02:13:59     3992.0     8039.0
#
#    split_frac
# 0   -0.018756
# 1   -0.026262
# 2   -0.022443
# 3    0.009097
# 4    0.006842

# %% [markdown]
# Where this split difference is less than zero, the person negative-split the race by that fraction.
# Let's do a distribution plot of this split fraction (see the following figure):

# %%
sns.displot(data['split_frac'], kde=False)
plt.axvline(0, color="k", linestyle="--");

# %%
sum(data.split_frac < 0)
# Out:
# 251

# %% [markdown]
# Out of nearly 40,000 participants, there were only 250 people who negative-split their marathon.
#
# Let's see whether there is any correlation between this split fraction and other variables. We'll do this using a `PairGrid`, which draws plots of all these correlations (see the following figure):

# %%
g = sns.PairGrid(data, vars=['age', 'split_sec', 'final_sec', 'split_frac'],
                 hue='gender', palette='RdBu_r')
g.map(plt.scatter, alpha=0.8)
g.add_legend();

# %% [markdown]
# It looks like the split fraction does not correlate particularly with age, but does correlate with the final time: faster runners tend to have closer to even splits on their marathon time. Let's zoom in on the histogram of split fractions separated by gender, shown in the following figure:

# %%
sns.kdeplot(data.split_frac[data.gender=='M'], label='men', shade=True)
sns.kdeplot(data.split_frac[data.gender=='W'], label='women', shade=True)
plt.xlabel('split_frac');
# Out:
# /tmp/ipython-input-550-1793497472.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data.split_frac[data.gender=='M'], label='men', shade=True)
# /tmp/ipython-input-550-1793497472.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data.split_frac[data.gender=='W'], label='women', shade=True)

# %% [markdown]
# The interesting thing here is that there are many more men than women who are running close to an even split!
# It almost looks like a bimodal distribution among the men and women. Let's see if we can suss out what's going on by looking at the distributions as a function of age.
#
# A nice way to compare distributions is to use a *violin plot*, shown in the following figure:

# %%
sns.violinplot(x="gender", y="split_frac", data=data,
               palette=["lightblue", "lightpink"]);

# %% [markdown]
# Let's look a little deeper, and compare these violin plots as a function of age (see the following figure). We'll start by creating a new column in the array that specifies the age range that each person is in, by decade:

# %%
data['age_dec'] = data.age.map(lambda age: 10 * (age // 10))
data.head()
# Out:
#    age gender           split           final  split_sec  final_sec  \
# 0   33      M 0 days 01:05:38 0 days 02:08:51     3938.0     7731.0
# 1   32      M 0 days 01:06:26 0 days 02:09:28     3986.0     7768.0
# 2   31      M 0 days 01:06:49 0 days 02:10:42     4009.0     7842.0
# 3   38      M 0 days 01:06:16 0 days 02:13:45     3976.0     8025.0
# 4   31      M 0 days 01:06:32 0 days 02:13:59     3992.0     8039.0
#
#    split_frac  age_dec
# 0   -0.018756       30
# 1   -0.026262       30
# 2   -0.022443       30
# 3    0.009097       30
# 4    0.006842       30

# %%
men = (data.gender == 'M')
women = (data.gender == 'W')

with sns.axes_style(style=None):
    sns.violinplot(x="age_dec", y="split_frac", hue="gender", data=data,
                   split=True, inner="quartile",
                   palette=["lightblue", "lightpink"]);

# %% [markdown]
# We can see where the distributions among men and women differ: the split distributions of men in their 20s to 50s show a pronounced overdensity toward lower splits when compared to women of the same age (or of any age, for that matter).
#
# Also surprisingly, it appears that the 80-year-old women seem to outperform *everyone* in terms of their split time, although this is likely a small number effect, as there are only a handful of runners in that range:

# %%
(data.age > 80).sum()
# Out:
# np.int64(7)

# %% [markdown]
# Back to the men with negative splits: who are these runners? Does this split fraction correlate with finishing quickly? We can plot this very easily. We'll use `regplot`, which will automatically fit a linear regression model to the data (see the following figure):

# %%
g = sns.lmplot(x='final_sec', y='split_frac', col='gender', data=data,
               markers=".", scatter_kws=dict(color='c'))
g.map(plt.axhline, y=0.0, color="k", ls=":");

# %% [markdown]
# **Spotify Songs**

# %% [markdown]
# ## Data

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd

file_path = "universal_top_spotify_songs.csv"

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "asaniczka/top-spotify-songs-in-73-countries-daily-updated",
  file_path,
)

print(df.head())
print(df.columns)
# Out:
# /tmp/ipython-input-556-1381435534.py:7: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#                spotify_id                name                artists  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ            Ordinary            Alex Warren
# 1  42UBPzRMh5yyz0EDPr6fr1            Manchild      Sabrina Carpenter
# 2  0FTmksd2dxiE5e3rWyJXs6     back to friends                  sombr
# 3  7so0lgd0zP2Sbgs2d7a1SZ    Die With A Smile  Lady Gaga, Bruno Mars
# 4  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER          Billie Eilish
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               1                0     NaN    2025-06-11
# 1           2              -1               48     NaN    2025-06-11
# 2           3               0                1     NaN    2025-06-11
# 3           4               0               -1     NaN    2025-06-11
# 4           5               1                0     NaN    2025-06-11
#
#    popularity  is_explicit  ...  key loudness mode  speechiness  acousticness  \
# 0          95        False  ...    2   -6.141    1       0.0600      0.704000
# 1          89         True  ...    7   -5.087    1       0.0572      0.122000
# 2          98        False  ...    1   -2.291    1       0.0301      0.000094
# 3          91        False  ...    6   -7.727    0       0.0317      0.289000
# 4         100        False  ...    2  -10.171    1       0.0358      0.200000
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.000007    0.0550    0.391  168.115               3
# 1          0.000000    0.3170    0.811  123.010               4
# 2          0.000088    0.0929    0.235   92.855               4
# 3          0.000000    0.1260    0.498  157.964               3
# 4          0.060800    0.1170    0.438  104.978               4
#
# [5 rows x 25 columns]
# Index(['spotify_id', 'name', 'artists', 'daily_rank', 'daily_movement',
#        'weekly_movement', 'country', 'snapshot_date', 'popularity',
#        'is_explicit', 'duration_ms', 'album_name', 'album_release_date',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')

# %% [markdown]
# ## Show the top 5 songs world wide

# %%
# Show the top 5 songs world wide
import matplotlib.pyplot as plt
df.dtypes

worldwide_songs = df[df['country'].isnull()]

# Top 5 songs
topWorldwide = worldwide_songs.sort_values(by='daily_rank').head(5)

print("Top 5 Songs Worldwide:")
display(topWorldwide)
# Out:
# Top 5 Songs Worldwide:
#                      spotify_id                  name  \
# 1669226  4m4BHvDfzIgj5LbQLuFiIp              CARNIVAL
# 378334   2plbrEY59IikOBgBGLjaoe      Die With A Smile
# 1208213  5N3hjp1WNayUPZrA8kJmJP  Please Please Please
# 1222813  5N3hjp1WNayUPZrA8kJmJP  Please Please Please
# 443222   2plbrEY59IikOBgBGLjaoe      Die With A Smile
#
#                            artists  daily_rank  daily_movement  \
# 1669226  Kanye West, Ty Dolla $ign           1               0
# 378334       Lady Gaga, Bruno Mars           1               0
# 1208213          Sabrina Carpenter           1               0
# 1222813          Sabrina Carpenter           1               0
# 443222       Lady Gaga, Bruno Mars           1               0
#
#          weekly_movement country snapshot_date  popularity  is_explicit  ...  \
# 1669226               49     NaN    2024-02-15          89         True  ...
# 378334                 1     NaN    2025-02-18          98        False  ...
# 1208213                0     NaN    2024-06-24          94         True  ...
# 1222813                0     NaN    2024-06-20          91         True  ...
# 443222                 1     NaN    2025-01-31         100        False  ...
#
#          key loudness mode  speechiness  acousticness  instrumentalness  \
# 1669226    1   -5.745    1       0.1520         0.192               0.0
# 378334     6   -7.777    0       0.0304         0.308               0.0
# 1208213    9   -6.073    1       0.0540         0.274               0.0
# 1222813    9   -6.073    1       0.0540         0.274               0.0
# 443222     6   -7.777    0       0.0304         0.308               0.0
#
#          liveness  valence    tempo  time_signature
# 1669226     0.338    0.290  148.241               4
# 378334      0.122    0.535  157.969               3
# 1208213     0.104    0.579  107.071               4
# 1222813     0.104    0.579  107.071               4
# 443222      0.122    0.535  157.969               3
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Artists top 3 songs and ranking

# %%
# artists top 3 songs and ranking
top_5_worldwide = worldwide_songs.sort_values(by='daily_rank').head(5)

x_labels = top_5_worldwide.apply(lambda row: f"{row['name']} by {row['artists']}", axis=1)
y_values = top_5_worldwide['daily_rank'].head(5)

plt.figure(figsize=(5, 10))
plt.bar(x_labels, y_values)
plt.xlabel("Song and Artist")
plt.ylabel("Daily Rank")
plt.title("Top 3 Worldwide Songs by Daily Rank")
plt.xticks(rotation=40, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 1 song data

# %%
# Top 1 song data

worldwide_songs = df[df['country'].isnull()]
top_song = worldwide_songs.sort_values(by='daily_rank').iloc[0]
top_song_id = top_song['name'], top_song['artists'], top_song['daily_rank'], top_song['country'], top_song['spotify_id']
print(f"Top song ID: {top_song_id}")
# Out:
# Top song ID: ('CARNIVAL', 'Kanye West, Ty Dolla $ign', np.int64(1), nan, '4m4BHvDfzIgj5LbQLuFiIp')

# %% [markdown]
# ## Billie Eilish

# %%
# billie eilish songs

# Data cleaning
df['artists'] = df['artists'].fillna('')

billie_eilish_songs = df[df['artists'].str.contains('Billie Eilish')]

print("Songs from Billie Eilish:")
display(billie_eilish_songs)

print("Top 3 songs from Billie Eilish:")
display(billie_eilish_songs.sort_values(by='daily_rank').head(3))

print("Top song from Billie Eilish:")
display(billie_eilish_songs.sort_values(by='daily_rank').iloc[0])

print("Top 3 countries that listen to Billie Eilish:")
display(billie_eilish_songs['country'].value_counts().head(3))
# Out:
# Songs from Billie Eilish:
#                      spotify_id  \
# 4        6dOtVTDdiauQNBQEDOtlAB
# 10       3QaPy1KgI7nu9FJEQUgn6h
# 81       6dOtVTDdiauQNBQEDOtlAB
# 88       3QaPy1KgI7nu9FJEQUgn6h
# 260      6dOtVTDdiauQNBQEDOtlAB
# ...                         ...
# 2110076  6wf7Yu7cxBSPrRlWeSeK0Q
# 2110113  0u2P5u6lvoDfwTYjAADbn4
# 2110138  6wf7Yu7cxBSPrRlWeSeK0Q
# 2110205  6wf7Yu7cxBSPrRlWeSeK0Q
# 2110285  6wf7Yu7cxBSPrRlWeSeK0Q
#
#                                                       name  \
# 4                                       BIRDS OF A FEATHER
# 10                                              WILDFLOWER
# 81                                      BIRDS OF A FEATHER
# 88                                              WILDFLOWER
# 260                                     BIRDS OF A FEATHER
# ...                                                    ...
# 2110076  What Was I Made For? [From The Motion Picture ...
# 2110113                               lovely (with Khalid)
# 2110138  What Was I Made For? [From The Motion Picture ...
# 2110205  What Was I Made For? [From The Motion Picture ...
# 2110285  What Was I Made For? [From The Motion Picture ...
#
#                        artists  daily_rank  daily_movement  weekly_movement  \
# 4                Billie Eilish           5               1                0
# 10               Billie Eilish          11               1                1
# 81               Billie Eilish          32               3               14
# 88               Billie Eilish          39               3               11
# 260              Billie Eilish          11               0               -2
# ...                        ...         ...             ...              ...
# 2110076          Billie Eilish          11              39                0
# 2110113  Billie Eilish, Khalid          48               2                0
# 2110138          Billie Eilish          23              27                0
# 2110205          Billie Eilish          40              10                0
# 2110285          Billie Eilish          20              30                0
#
#         country snapshot_date  popularity  is_explicit  ...  key loudness  \
# 4           NaN    2025-06-11         100        False  ...    2  -10.171
# 10          NaN    2025-06-11          96        False  ...    6  -12.002
# 81           ZA    2025-06-11         100        False  ...    2  -10.171
# 88           ZA    2025-06-11          96        False  ...    6  -12.002
# 260          US    2025-06-11         100        False  ...    2  -10.171
# ...         ...           ...         ...          ...  ...  ...      ...
# 2110076      BE    2023-10-18          96        False  ...    0  -17.665
# 2110113      BE    2023-10-18          90        False  ...    4  -10.109
# 2110138      AU    2023-10-18          96        False  ...    0  -17.665
# 2110205      AT    2023-10-18          96        False  ...    0  -17.665
# 2110285      AE    2023-10-18          96        False  ...    0  -17.665
#
#         mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 4          1       0.0358         0.200          0.060800     0.117    0.438
# 10         0       0.0431         0.612          0.000271     0.170    0.126
# 81         1       0.0358         0.200          0.060800     0.117    0.438
# 88         0       0.0431         0.612          0.000271     0.170    0.126
# 260        1       0.0358         0.200          0.060800     0.117    0.438
# ...      ...          ...           ...               ...       ...      ...
# 2110076    1       0.0307         0.959          0.000001     0.098    0.142
# 2110113    0       0.0333         0.934          0.000000     0.095    0.120
# 2110138    1       0.0307         0.959          0.000001     0.098    0.142
# 2110205    1       0.0307         0.959          0.000001     0.098    0.142
# 2110285    1       0.0307         0.959          0.000001     0.098    0.142
#
#            tempo  time_signature
# 4        104.978               4
# 10       148.101               4
# 81       104.978               4
# 88       148.101               4
# 260      104.978               4
# ...          ...             ...
# 2110076   78.403               4
# 2110113  115.284               4
# 2110138   78.403               4
# 2110205   78.403               4
# 2110285   78.403               4
#
# [35287 rows x 25 columns]
# Top 3 songs from Billie Eilish:
#                      spotify_id                name        artists  \
# 1321113  629DixmZGHc7ILtEntuiWE               LUNCH  Billie Eilish
# 1044013  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER  Billie Eilish
# 1043963  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER  Billie Eilish
#
#          daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 1321113           1               0                2      BE    2024-05-25
# 1044013           1               1                1     NaN    2024-08-08
# 1043963           1               0                0      AE    2024-08-09
#
#          popularity  is_explicit  ...  key loudness mode  speechiness  \
# 1321113          93        False  ...   11   -7.981    0       0.0643
# 1044013          99        False  ...    2  -10.171    1       0.0358
# 1043963          99        False  ...    2  -10.171    1       0.0358
#
#          acousticness  instrumentalness  liveness  valence    tempo  \
# 1321113        0.0452            0.0823    0.0632    0.945  124.987
# 1044013        0.2000            0.0608    0.1170    0.438  104.978
# 1043963        0.2000            0.0608    0.1170    0.438  104.978
#
#          time_signature
# 1321113               4
# 1044013               4
# 1043963               4
#
# [3 rows x 25 columns]
# Top song from Billie Eilish:
# spotify_id            629DixmZGHc7ILtEntuiWE
# name                                   LUNCH
# artists                        Billie Eilish
# daily_rank                                 1
# daily_movement                             0
# weekly_movement                            2
# country                                   BE
# snapshot_date                     2024-05-25
# popularity                                93
# is_explicit                            False
# duration_ms                           179586
# album_name              HIT ME HARD AND SOFT
# album_release_date                2024-05-17
# danceability                           0.893
# energy                                   0.4
# key                                       11
# loudness                              -7.981
# mode                                       0
# speechiness                           0.0643
# acousticness                          0.0452
# instrumentalness                      0.0823
# liveness                              0.0632
# valence                                0.945
# tempo                                124.987
# time_signature                             4
# Name: 1321113, dtype: object
# Top 3 countries that listen to Billie Eilish:
# country
# SA    1453
# AU    1268
# NZ    1170
# Name: count, dtype: int64

# %% [markdown]
# ## Songs with highest daily movement

# %%
top_movement_songs_info = top_movement_songs[['spotify_id', 'name', 'artists']]
display(top_movement_songs_info)
# Out:
#                      spotify_id                          name  \
# 679986   25mDnFOFyPmebNAok8mavk                       Islanda
# 1950733  11oUseW6uGWlPDQ77M2GT1                         Bejby
# 1564914  0kdqcbwei4MDWFEX5f33yG          Bling-Bang-Bang-Born
# 679336   6YSq1MHTG61D0p489GqcLA  Siste Dans - fra Snøsøsteren
# 680486   0BX3JjlMC0KOUD1zqXc3Eg                   Kataramenos
# 680536   1y7dY7Xu4nWM4SK2dEnoAT                         Alpha
# 680586   6zLzNEyVqtyZoohE75maSy                          Diva
# 680636   0l0vcZMU7AOeQmUIREoI2U                Qué Pasaría...
# 679036   7ku8Eh5guoneeMmuuzzWmN    Choć nie widać na zewnątrz
# 492865   0fvFSGvEAPDDMfweKvDJVa                      Gesegnet
#
#                                          artists
# 679986                 Pinguini Tattici Nucleari
# 1950733                                     Sima
# 1564914                              Creepy Nuts
# 679336                                    Delara
# 680486                           Roi 6/12, Myron
# 680536                             Damso, Kalash
# 680586                            Averagekidluke
# 680636                 Rauw Alejandro, Bad Bunny
# 679036   White 2115, Bedoes 2115, Kubi Producent
# 492865                       Apache 207, Luciano

# %% [markdown]
# ## Song with highest daily movement:

# %%
plotting_data = filtered_songs_data[['snapshot_date', 'daily_rank', 'name', 'artists']].copy()
plotting_data['song_artist'] = plotting_data.apply(lambda row: f"{row['name']} by {row['artists']}", axis=1)
plotting_data = plotting_data[['snapshot_date', 'daily_rank', 'song_artist']]
display(plotting_data.head())
# Out:
#         snapshot_date  daily_rank    song_artist
# 1953104    2023-11-30          22  Bejby by Sima
# 1950733    2023-11-30           1  Bejby by Sima
# 1947083    2023-12-01           1  Bejby by Sima
# 1949448    2023-12-01          16  Bejby by Sima
# 1943434    2023-12-02           2  Bejby by Sima

# %% [markdown]
# ## Ranks over time:

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(data=plotting_data, x='snapshot_date', y='daily_rank', hue='song_artist')
plt.title("Daily Rank of  Songs with High Daily Movement Over Time")
plt.xlabel("Date")
plt.ylabel("Daily Rank")
plt.gca().invert_yaxis()
plt.xticks(rotation=45)
plt.tight_layout()

plt.legend(title='Song and Artist', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
